# %% [markdown]
# <a href="https://colab.research.google.com/github/gcarmonaar/Diplomado-CDP-24/blob/main/DiplomadoCD_Modulo2_clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.rand(10,4),
                columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.608136  0.429240  0.987120  0.126226
# 1  0.223365  0.851271  0.861660  0.675615
# 2  0.346517  0.217283  0.282961  0.589503
# 3  0.428720  0.648018  0.964967  0.529552
# 4  0.228287  0.765180  0.594385  0.672000

# %%
df.shape
# Out:
# (10, 4)

# %%
df["A"]
# Out:
# 0    0.608136
# 1    0.223365
# 2    0.346517
# 3    0.428720
# 4    0.228287
# 5    0.626701
# 6    0.439345
# 7    0.666491
# 8    0.180969
# 9    0.794865
# Name: A, dtype: float64

# %%
df.loc[:,["A","B"]]
# Out:
#           A         B
# 0  0.608136  0.429240
# 1  0.223365  0.851271
# 2  0.346517  0.217283
# 3  0.428720  0.648018
# 4  0.228287  0.765180
# 5  0.626701  0.934097
# 6  0.439345  0.445027
# 7  0.666491  0.690544
# 8  0.180969  0.808460
# 9  0.794865  0.087755

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x="A", y="B")
# Out:
# <Axes: xlabel='A'>

# %%
df.plot(subplots=True, figsize=(10, 5))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["A"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'A'}>, <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'C'}>, <Axes: title={'center': 'D'}>]],
#       dtype=object)

# %%
df["A"].hist()
# Out:
# <Axes: >

# %%
df.plot.hist(orientation="horizontal", cumulative=False)
# Out:
# <Axes: xlabel='Frequency'>

# %%
df.plot.area(stacked=False)
# Out:
# <Axes: >

# %%
df["A"].plot.area(stacked=False)
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.scatter(x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot.scatter(x="A", y="B", c="teal", s=100, marker="*")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot.scatter(x="A", y="B", c="D", s=100)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot.scatter(x="A", y="B", c="blue", s="D")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df["A"].plot.pie();

# %%
datos = pd.Series(np.random.rand(5))
datos
# Out:
# 0    0.124931
# 1    0.893923
# 2    0.200464
# 3    0.208069
# 4    0.586134
# dtype: float64

# %%
datos.plot.pie()
# Out:
# <Axes: >

# %%
df.plot.pie(subplots=True, figsize=(15, 15))
# Out:
# array([<Axes: ylabel='A'>, <Axes: ylabel='B'>, <Axes: ylabel='C'>,
#        <Axes: ylabel='D'>], dtype=object)
